# %% [markdown]
# https://www.linkedin.com/pulse/text-classification-using-bag-words-approach-nltk-scikit-rajendran/

# %%
import pandas as pd
dataset = pd.read_csv('spam.csv', encoding='ISO-8859-1');

# %%
dataset
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
#preprocess the data
#remove non alphabetic characters like numbers and punctation
import re
sms
sms = re.sub('[^A-Za-z]', ' ', sms)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-17895c1050f3> in <module>
#       2 #remove non alphabetic characters like numbers and punctation
#       3 import re
# ----> 4 sms = re.sub('[^A-Za-z]', ' ', sms)
#
# NameError: name 'sms' is not defined
